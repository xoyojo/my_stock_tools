# %%
import akshare as ak

macro_china_industrial_production_yoy_df = ak.macro_china_industrial_production_yoy()
print(macro_china_industrial_production_yoy_df)
# Out:
# 1990-03-01    5.0
# 1990-04-01    0.8
# 1990-05-01    1.7
# 1990-06-01    3.3
# 1990-07-01    5.0
#              ...
# 2022-10-24    6.3
# 2022-11-15    5.0
# 2022-12-15    2.2
# 2023-01-17    1.3
# 2023-03-15    2.4
# Name: china_industrial_production_yoy, Length: 373, dtype: float64
# c:\Users\xoyoj\miniconda3\envs\juejin\lib\site-packages\akshare\economic\macro_china.py:672: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_df = temp_df.append(temp_se)

# %%
#绘制折线图
macro_china_industrial_production_yoy_df.plot()
# Out:
# <Axes: >
